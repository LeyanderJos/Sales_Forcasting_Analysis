# %%
import pandas as pd

# %%
df_store = pd.read_csv("stores_data_set.csv")

# %%
df_store.head(5)
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
df = pd.read_csv("sales_data_set.csv")

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
d = df.merge(df_store,on=["Store"],how ="inner")

# %%
d.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0      1     1  05/02/2010      24924.50      False    A  151315
# 1      1     1  12/02/2010      46039.49       True    A  151315
# 2      1     1  19/02/2010      41595.55      False    A  151315
# 3      1     1  26/02/2010      19403.54      False    A  151315
# 4      1     1  05/03/2010      21827.90      False    A  151315

# %%
# Feature

# %%
df1 = pd.read_csv("Features_data_set.csv")

# %%
df = df1.merge(d,on = ['Store','Date'],how = 'inner')

# %%
df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  05/02/2010        42.31       2.572        NaN        NaN
# 2      1  05/02/2010        42.31       2.572        NaN        NaN
# 3      1  05/02/2010        42.31       2.572        NaN        NaN
# 4      1  05/02/2010        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday_x  \
# 0        NaN        NaN        NaN  211.096358         8.106        False
# 1        NaN        NaN        NaN  211.096358         8.106        False
# 2        NaN        NaN        NaN  211.096358         8.106        False
# 3        NaN        NaN        NaN  211.096358         8.106        False
# 4        NaN        NaN        NaN  211.096358         8.106        False
#
#    Dept  Weekly_Sales  IsHoliday_y Type    Size
# 0     1      24924.50        False    A  151315
# 1     2      50605.27        False    A  151315
# 2     3      13740.12        False    A  151315
# 3     4      39954.04        False    A  151315
# 4     5      32229.38        False    A  151315

# %%
df.drop(['IsHoliday_y'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  05/02/2010        42.31       2.572        NaN        NaN
# 2      1  05/02/2010        42.31       2.572        NaN        NaN
# 3      1  05/02/2010        42.31       2.572        NaN        NaN
# 4      1  05/02/2010        42.31       2.572        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday_x  \
# 0        NaN        NaN        NaN  211.096358         8.106        False
# 1        NaN        NaN        NaN  211.096358         8.106        False
# 2        NaN        NaN        NaN  211.096358         8.106        False
# 3        NaN        NaN        NaN  211.096358         8.106        False
# 4        NaN        NaN        NaN  211.096358         8.106        False
#
#    Dept  Weekly_Sales Type    Size
# 0     1      24924.50    A  151315
# 1     2      50605.27    A  151315
# 2     3      13740.12    A  151315
# 3     4      39954.04    A  151315
# 4     5      32229.38    A  151315

# %%
df.isna().sum()
# Out:
# Store                0
# Date                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_x          0
# Dept                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_x     0
# Dept            0
# Weekly_Sales    0
# Type            0
# Size            0
# dtype: int64

# %%
df.describe()
# Out:
#                Store    Temperature     Fuel_Price      MarkDown1  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      60.090059       3.361027    2590.074819
# std        12.785297      18.447931       0.458515    6052.385934
# min         1.000000      -2.060000       2.472000       0.000000
# 25%        11.000000      46.680000       2.933000       0.000000
# 50%        22.000000      62.090000       3.452000       0.000000
# 75%        33.000000      74.280000       3.738000    2809.050000
# max        45.000000     100.140000       4.468000   88646.760000
#
#            MarkDown2      MarkDown3      MarkDown4      MarkDown5  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      879.974298     468.087665    1083.132268    1662.772385
# std      5084.538801    5528.873453    3894.529945    4207.629321
# min      -265.760000     -29.100000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         2.200000       4.540000     425.290000    2168.040000
# max    104519.540000  141630.610000   67474.850000  108519.280000
#
#                  CPI   Unemployment           Dept   Weekly_Sales  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      171.201947       7.960289      44.260317   15981.258123
# std        39.159276       1.863296      30.492054   22711.183519
# min       126.064000       3.879000       1.000000   -4988.940000
# 25%       132.022667       6.891000      18.000000    2079.650000
# 50%       182.318780       7.866000      37.000000    7612.030000
# 75%       212.416993       8.572000      74.000000   20205.852500
# max       227.232807      14.313000      99.000000  693099.360000
#
#                 Size
# count  421570.000000
# mean   136727.915739
# std     60980.583328
# min     34875.000000
# 25%     93638.000000
# 50%    140167.000000
# 75%    202505.000000
# max    219622.000000

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\LEYANDER\AppData\Local\Temp\ipykernel_15940\936118274.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = pd.to_datetime(df["Date"]).dt.day
df["Week"] = df["Date"].dt.isocalendar().week

# %%
df[(df['Weekly_Sales'] < 0)].count()
# Out:
# Store           1285
# Date            1285
# Temperature     1285
# Fuel_Price      1285
# MarkDown1       1285
# MarkDown2       1285
# MarkDown3       1285
# MarkDown4       1285
# MarkDown5       1285
# CPI             1285
# Unemployment    1285
# IsHoliday_x     1285
# Dept            1285
# Weekly_Sales    1285
# Type            1285
# Size            1285
# Year            1285
# Month           1285
# Day             1285
# Week            1285
# dtype: int64

# %%
df.drop(df[df['Weekly_Sales'] < 0].index,inplace = True)

# %%
df.rename(columns = {"IsHoliday_x":"IsHoliday"},inplace = True)

# %%
df.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 1      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 2      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 3      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
# 4      1 2010-05-02        42.31       2.572        0.0        0.0        0.0
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        0.0        0.0  211.096358         8.106      False     1
# 1        0.0        0.0  211.096358         8.106      False     2
# 2        0.0        0.0  211.096358         8.106      False     3
# 3        0.0        0.0  211.096358         8.106      False     4
# 4        0.0        0.0  211.096358         8.106      False     5
#
#    Weekly_Sales Type    Size  Year  Month  Day  Week
# 0      24924.50    A  151315  2010      5    2    17
# 1      50605.27    A  151315  2010      5    2    17
# 2      13740.12    A  151315  2010      5    2    17
# 3      39954.04    A  151315  2010      5    2    17
# 4      32229.38    A  151315  2010      5    2    17

# %%
df["Markdown"] = (df[["MarkDown1", "MarkDown2", "MarkDown3", "MarkDown4", "MarkDown5"]] == 0).all(axis=1).astype(int)

# %%
df["Markdown"].value_counts()
# Out:
# 1    269337
# 0    150948
# Name: Markdown, dtype: int64

# %%
#True - 1,False -0
df.IsHoliday.replace({True :1,False:0},inplace = True)

# %%
df.Type.replace({"A":1,"B":0,"C":-1},inplace = True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\LEYANDER\AppData\Local\Temp\ipykernel_15940\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Type', y='Weekly_Sales', data=df, estimator=sum)  # sum instead of the default mean
plt.title('Total Sales by Store Type')
plt.xlabel('Store Type')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Temperature', y='Weekly_Sales', data=df)
plt.title('Temperature vs Average Sales with Regression Line')
plt.xlabel('Temperature')
plt.ylabel('Average Sales')
plt.show()

# %%
df.to_csv("Sales_Markdown.csv")

# %%
df
# Out:
#         Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1 2010-05-02        42.31       2.572       0.00       0.00
# 1           1 2010-05-02        42.31       2.572       0.00       0.00
# 2           1 2010-05-02        42.31       2.572       0.00       0.00
# 3           1 2010-05-02        42.31       2.572       0.00       0.00
# 4           1 2010-05-02        42.31       2.572       0.00       0.00
# ...       ...        ...          ...         ...        ...        ...
# 421565     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421566     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421567     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421568     45 2012-10-26        58.85       3.882    4018.91      58.08
# 421569     45 2012-10-26        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  ...  IsHoliday  Dept  \
# 0             0.0       0.00       0.00  211.096358  ...          0     1
# 1             0.0       0.00       0.00  211.096358  ...          0     2
# 2             0.0       0.00       0.00  211.096358  ...          0     3
# 3             0.0       0.00       0.00  211.096358  ...          0     4
# 4             0.0       0.00       0.00  211.096358  ...          0     5
# ...           ...        ...        ...         ...  ...        ...   ...
# 421565      100.0     211.94     858.33  192.308899  ...          0    93
# 421566      100.0     211.94     858.33  192.308899  ...          0    94
# 421567      100.0     211.94     858.33  192.308899  ...          0    95
# 421568      100.0     211.94     858.33  192.308899  ...          0    97
# 421569      100.0     211.94     858.33  192.308899  ...          0    98
#
#         Weekly_Sales  Type    Size  Year  Month  Day  Week  Markdown
# 0           24924.50     1  151315  2010      5    2    17         1
# 1           50605.27     1  151315  2010      5    2    17         1
# 2           13740.12     1  151315  2010      5    2    17         1
# 3           39954.04     1  151315  2010      5    2    17         1
# 4           32229.38     1  151315  2010      5    2    17         1
# ...              ...   ...     ...   ...    ...  ...   ...       ...
# 421565       2487.80     0  118221  2012     10   26    43         0
# 421566       5203.31     0  118221  2012     10   26    43         0
# 421567      56017.47     0  118221  2012     10   26    43         0
# 421568       6817.48     0  118221  2012     10   26    43         0
# 421569       1076.80     0  118221  2012     10   26    43         0
#
# [420285 rows x 21 columns]

# %%
# Random Forest

# %%
y = df["Weekly_Sales"]
x = df.drop(["Weekly_Sales","Date","Size",'Week','Markdown'],axis = 1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=40)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

     

from sklearn.model_selection import cross_val_score, KFold
     

num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# Cross-Validation R-squared Scores: [0.96382635 0.9603146  0.96371487 0.96759361 0.9581854 ]
# Average Cross-Validation R-squared Score: 0.9627269657431713

# %%
# ADA BOOST

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Initialize the base estimator (weak learner)
base_estimator = DecisionTreeRegressor(max_depth=100)

# Initialize the AdaBoostRegressor model
model = AdaBoostRegressor(base_estimator=base_estimator)

num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# C:\Users\LEYANDER\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\LEYANDER\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\LEYANDER\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\LEYANDER\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\LEYANDER\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Cross-Validation R-squared Scores: [0.96779875 0.96331975 0.96814297 0.96997185 0.96002356]
# Average Cross-Validation R-squared Score: 0.9658513745142846

# %%
#GRADIENT BOOST

# %%
from sklearn.ensemble import GradientBoostingRegressor
y = df["Weekly_Sales"]
x = df.drop(["Weekly_Sales","Date","Size",'Week','Markdown'],axis = 1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

model = GradientBoostingRegressor()

num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores_r2 = cross_val_score(model, x, y, cv=kf, scoring='r2')

# Display the cross-validation R-squared scores
print("Cross-Validation R-squared Scores:", cv_scores_r2)

# Calculate the average R-squared score
avg_cv_score_r2 = cv_scores_r2.mean()
print("Average Cross-Validation R-squared Score:", avg_cv_score_r2)
# Out:
# Cross-Validation R-squared Scores: [0.71262809 0.69643529 0.70764944 0.71814421 0.68349112]
# Average Cross-Validation R-squared Score: 0.7036696299874097
